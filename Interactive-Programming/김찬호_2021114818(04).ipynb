# %% [markdown]
#  성명:김찬호
#
#  학과:IT대학 컴퓨터학부
#
#  주차:4주차
#
#  학번:2021114818

# %%
chunja_moon = """1|天地玄黃|천지현황|天(하늘 천)地(땅 지)玄(검을 현)黃(누를 황)|하늘은 위에 있어 그 빛이 검고 땅은 아래 있어서 그 빛이 누르다.
2|宇宙洪荒|우주홍황|宇(집 우)宙(집 주)洪(넓을 홍)荒(거칠 황)|하늘과 땅 사이는 넓고 커서 끝이 없다. 즉 세상의 넓음을 말한다.
3|日月盈昃|일월영측|日(날 일)月(달 월)盈(찰 영)昃(기울 측)|해는 서쪽으로 기울고 달도 차면 점차 이지러진다. 즉 우주의 진리를 말한다.
4|辰宿列張|진숙열장|辰(별 진)宿(잘 숙)列(벌일 열)張(베풀 장)|성좌가 해 달과 같이 하늘에 넓게 벌려져 있음을 말한다.
5|寒來暑往|한래서왕|寒(찰 한)來(올 래)暑(더울 서)往(갈 왕)|찬 것이 오면 더운 것이 가고 더운 것이 오면 찬 것이 간다. 즉 사철의 바뀜을 말한다.
6|秋收冬藏|추수동장|秋(가을 추)收(거둘 수)冬(겨울 동)藏(감출 장)|가을에 곡식을 거두고 겨울이 오면 그것을 감춰 들인다.
7|閏餘成歲|윤여성세|閏(윤달 윤)餘(남을 여)成(이룰 성)歲(해 세)|일년 이십사절기 나머지 시각을 모아 윤달로 하여 해를 이루었다.
8|律呂調陽|율려조양|律(가락 률)呂(음률 려)調(고를 조)陽(볕 양)|천지간의 양기를 고르게 하니 즉 율은 양이요 여는 음이다.
9|雲騰致雨|운등치우|雲(구름 운)騰(오를 등)致(이를 치)雨(비 우)|수증기가 올라가서 구름이 되고 냉기를 만나 비가 된다. 즉 자연의 기상을 말한다.
10|露結爲霜|노결위상|露(이슬 로)結(맺을 결)爲(할 위)霜(서리 상)|이슬이 맺어 서리가 되니 밤기운이 풀잎에 물방울처럼 이슬을 이룬다.
11|金生麗水|금생여수|金(쇠 금)生(낳을 생)麗(고울 려)水(물 수)|금은 여수에서 나니 여수는 중국의 지명이다.
12|玉出崑岡|옥출곤강|玉(구슬 옥)出(날 출)崑(메 곤)岡(메 강)|옥은 곤강에서 나니 곤강은 역시 중국의 산 이름이다.
13|劍號巨闕|검호거궐|劍(칼 검)號(이름 호)巨(클 거)闕(대궐 궐)|거궐은 칼이름이고 구야자가 지은 보검이다. 즉 조나라의 국보다.
14|珠稱夜光|주칭야광|珠(구슬 주)稱(일컬을 칭)夜(밤 야)光(빛 광)|구슬의 빛이 밤의 낮 같은 고로 야광이라 칭하였다.
15|果珍李柰|과진이내|果(과실 과)珍(보배 진)李(오얏 리)柰(능금나무 내)|과실 중에 오얏과 능금나무의 그 진미가 으뜸임을 말한다.
16|菜重芥薑|채중개강|菜(나물 채)重(무거울 중)芥(겨자 개)薑(생강 강)|나물은 겨자와 생강이 중하다.
17|海鹹河淡|해함하담|海(바다 해)鹹(짤 함)河(물 하)淡(묽을 담)|바다 물은 짜고 밀물은 맛도 없고 맑다.
18|鱗潛羽翔|인잠우상|鱗(비늘 린)潛(잠길 잠)羽(깃 우)翔(높이 날 상)|비늘 있는 고기는 물 속에 잠기고 날개 있는 새는 공중에 난다.
19|龍師火帝|용사화제|龍(용 룡)師(스승 사)火(불 화)帝(임금 제)|복희씨는 용으로써 벼슬을 기록하고 신농씨는 불로써 기록하였다.
20|鳥官人皇|조관인황|鳥(새 조)官(벼슬 관)人(사람 인)皇(임금 황)|소호는 새로써 벼슬을 기록하고 황제는 인문을 갖추었으므로 인황이라 하였다."""




chunja_dict ={}
chunja_lines = chunja_moon.splitlines()

for i in range(len(chunja_lines)):
    chunja_list = chunja_lines[i].split('|')
    
    key         =chunja_list[2]
    value       =tuple([ chunja_list[0],chunja_list[1],chunja_list[3],chunja_list[-1]])
    chunja_dict[key] =value
    
for key, value in chunja_dict.items():
    print('='*80)
    value_번호    = value[0]
    value_한자    = value[1]
    value_한자뜻   = value[2]
    value_한글뜻    = value[-1]
    
    print(f'{key} { value_번호: >2s}')
    print(f'[{value_한자}]')
    print(f'한자풀이 : {value_한자뜻}')
    print(f'한글풀이 : {value_한글뜻}')
    
print('#'*80)
# Out:
# ================================================================================
# 천지현황  1
# [天地玄黃]
# 한자풀이 : 天(하늘 천)地(땅 지)玄(검을 현)黃(누를 황)
# 한글풀이 : 하늘은 위에 있어 그 빛이 검고 땅은 아래 있어서 그 빛이 누르다.
# ================================================================================
# 우주홍황  2
# [宇宙洪荒]
# 한자풀이 : 宇(집 우)宙(집 주)洪(넓을 홍)荒(거칠 황)
# 한글풀이 : 하늘과 땅 사이는 넓고 커서 끝이 없다. 즉 세상의 넓음을 말한다.
# ================================================================================
# 일월영측  3
# [日月盈昃]
# 한자풀이 : 日(날 일)月(달 월)盈(찰 영)昃(기울 측)
# 한글풀이 : 해는 서쪽으로 기울고 달도 차면 점차 이지러진다. 즉 우주의 진리를 말한다.
# ================================================================================
# 진숙열장  4
# [辰宿列張]
# 한자풀이 : 辰(별 진)宿(잘 숙)列(벌일 열)張(베풀 장)
# 한글풀이 : 성좌가 해 달과 같이 하늘에 넓게 벌려져 있음을 말한다.
# ================================================================================
# 한래서왕  5
# [寒來暑往]
# 한자풀이 : 寒(찰 한)來(올 래)暑(더울 서)往(갈 왕)
# 한글풀이 : 찬 것이 오면 더운 것이 가고 더운 것이 오면 찬 것이 간다. 즉 사철의 바뀜을 말한다.
# ================================================================================
# 추수동장  6
# [秋收冬藏]
# 한자풀이 : 秋(가을 추)收(거둘 수)冬(겨울 동)藏(감출 장)
# 한글풀이 : 가을에 곡식을 거두고 겨울이 오면 그것을 감춰 들인다.
# ================================================================================
# 윤여성세  7
# [閏餘成歲]
# 한자풀이 : 閏(윤달 윤)餘(남을 여)成(이룰 성)歲(해 세)
# 한글풀이 : 일년 이십사절기 나머지 시각을 모아 윤달로 하여 해를 이루었다.
# ================================================================================
# 율려조양  8
# [律呂調陽]
# 한자풀이 : 律(가락 률)呂(음률 려)調(고를 조)陽(볕 양)
# 한글풀이 : 천지간의 양기를 고르게 하니 즉 율은 양이요 여는 음이다.
# ================================================================================
# 운등치우  9
# [雲騰致雨]
# 한자풀이 : 雲(구름 운)騰(오를 등)致(이를 치)雨(비 우)
# 한글풀이 : 수증기가 올라가서 구름이 되고 냉기를 만나 비가 된다. 즉 자연의 기상을 말한다.
# ================================================================================
# 노결위상 10
# [露結爲霜]
# 한자풀이 : 露(이슬 로)結(맺을 결)爲(할 위)霜(서리 상)
# 한글풀이 : 이슬이 맺어 서리가 되니 밤기운이 풀잎에 물방울처럼 이슬을 이룬다.
# ================================================================================
# 금생여수 11
# [金生麗水]
# 한자풀이 : 金(쇠 금)生(낳을 생)麗(고울 려)水(물 수)
# 한글풀이 : 금은 여수에서 나니 여수는 중국의 지명이다.
# ================================================================================
# 옥출곤강 12
# [玉出崑岡]
# 한자풀이 : 玉(구슬 옥)出(날 출)崑(메 곤)岡(메 강)
# 한글풀이 : 옥은 곤강에서 나니 곤강은 역시 중국의 산 이름이다.
# ================================================================================
# 검호거궐 13
# [劍號巨闕]
# 한자풀이 : 劍(칼 검)號(이름 호)巨(클 거)闕(대궐 궐)
# 한글풀이 : 거궐은 칼이름이고 구야자가 지은 보검이다. 즉 조나라의 국보다.
# ================================================================================
# 주칭야광 14
# [珠稱夜光]
# 한자풀이 : 珠(구슬 주)稱(일컬을 칭)夜(밤 야)光(빛 광)
# 한글풀이 : 구슬의 빛이 밤의 낮 같은 고로 야광이라 칭하였다.
# ================================================================================
# 과진이내 15
# [果珍李柰]
# 한자풀이 : 果(과실 과)珍(보배 진)李(오얏 리)柰(능금나무 내)
# 한글풀이 : 과실 중에 오얏과 능금나무의 그 진미가 으뜸임을 말한다.
# ================================================================================
# 채중개강 16
# [菜重芥薑]
# 한자풀이 : 菜(나물 채)重(무거울 중)芥(겨자 개)薑(생강 강)
# 한글풀이 : 나물은 겨자와 생강이 중하다.
# ================================================================================
# 해함하담 17
# [海鹹河淡]
# 한자풀이 : 海(바다 해)鹹(짤 함)河(물 하)淡(묽을 담)
# 한글풀이 : 바다 물은 짜고 밀물은 맛도 없고 맑다.
# ================================================================================
# 인잠우상 18
# [鱗潛羽翔]
# 한자풀이 : 鱗(비늘 린)潛(잠길 잠)羽(깃 우)翔(높이 날 상)
# 한글풀이 : 비늘 있는 고기는 물 속에 잠기고 날개 있는 새는 공중에 난다.
# ================================================================================
# 용사화제 19
# [龍師火帝]
# 한자풀이 : 龍(용 룡)師(스승 사)火(불 화)帝(임금 제)
# 한글풀이 : 복희씨는 용으로써 벼슬을 기록하고 신농씨는 불로써 기록하였다.
# ================================================================================
# 조관인황 20
# [鳥官人皇]
# 한자풀이 : 鳥(새 조)官(벼슬 관)人(사람 인)皇(임금 황)
# 한글풀이 : 소호는 새로써 벼슬을 기록하고 황제는 인문을 갖추었으므로 인황이라 하였다.
# ################################################################################
